# %% [markdown]
# <a href="https://colab.research.google.com/github/razayas15/DA1-TPO-2026-CostaApp/blob/main/Jueves_ExploracionDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://data.buenosaires.gob.ar/dataset/mercado-laboral/resource/345ed5c8-5349-4241-94d8-8548ff18bc7e/download"
df = pd.read_csv(url)
display(df.head(10))
# Out:
#    anio   sexo  porc_poblacion      nivel_instruccion
# 0  2012  TOTAL        2.189579    Primario incompleto
# 1  2012  TOTAL        6.642133      Primario completo
# 2  2012  TOTAL       13.436106  Secundario incompleto
# 3  2012  TOTAL       17.992655    Secundario completo
# 4  2012  TOTAL       24.981459    Superior incompleto
# 5  2012  TOTAL       34.758068      Superior completo
# 6  2012      m        2.586231    Primario incompleto
# 7  2012      m        5.700055      Primario completo
# 8  2012      m       10.080588  Secundario incompleto
# 9  2012      m       16.773670    Secundario completo
